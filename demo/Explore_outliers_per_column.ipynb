# %%
from outliers.column_wise import remove_outliers_numeric, plot_distribution_numeric
import pandas as pd
import numpy as np

data = pd.read_csv('../data/data_demo.csv')

data.head()
# Out:
#    rooms  garages  useful_area      value  interior_quality  time_on_market  \
# 0    3.0      1.0        105.0  1038640.0                 2       31.787079
# 1    3.0      2.0         76.0   606405.0                 4      209.468842
# 2    3.0      1.0        123.0  1534500.0                 1       38.000000
# 3    3.0      2.0        180.0  1131950.0                 5      154.000000
# 4    3.0      1.0         67.0   452672.0                 4       15.000000
#
#    has_outlier
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
plot_distribution_numeric(data,'value','distribution price')
plot_distribution_numeric(data, 'value', title = 'distribution price without extreme values', mode='without_outliers')

# %%
plot_distribution_numeric(data,'useful_area','distribution useful_area')
plot_distribution_numeric(data, 'useful_area', title = 'distribution useful_area without extreme values', mode='without_outliers')

# %%
plot_distribution_numeric(data,'time_on_market','distribution time_on_market')
plot_distribution_numeric(data, 'time_on_market', title = 'distribution time_on_market without extreme values', mode='without_outliers')

# %%
plot_distribution_numeric(data,'interior_quality','distribution interior_quality')
plot_distribution_numeric(data, 'interior_quality', title = 'distribution interior quality without extreme values', mode='without_outliers')

# %%
plot_distribution_numeric(data,'garages','distribution garages')
plot_distribution_numeric(data, 'garages', title = 'distribution garages without extreme values', mode='without_outliers')

# %%
plot_distribution_numeric(data,'rooms','distribution rooms')
plot_distribution_numeric(data, 'rooms', title = 'distribution rooms without extreme values', mode='without_outliers')
